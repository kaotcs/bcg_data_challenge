# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [raw]
# C:\Users\Ernesto\Desktop\workspace\BCG_challenge\Dados - GAMMA Challenge 2022\Producao Agricola Municipal (PAM)

# %%
filepath = "../dados/Producao/PAM.xlsx"

# %%
df = pd.read_excel(filepath)

# %% [markdown]
# - quais os municipios do Amazonas com maior producao, maior volume de importacao e maior sustentabilidade?
#
# - municipios com maior producao, maior volume de importacao e maior qualidade de vida da populacao?
#
# - desmatamento: tem dados de queimadas
#
# - indicadores sociais: renda media da populacao, taxa de desemprego

# %%
df_mun = pd.read_excel(filepath, sheet_name="Variáveis externas")

# %%
df_mun
# Out:
#       Região Geográfica Intermediária Nome Região Geográfica Intermediária  \
# 0                                1102                            Ji-Paraná
# 1                                1102                            Ji-Paraná
# 2                                1101                          Porto Velho
# 3                                1102                            Ji-Paraná
# 4                                1101                          Porto Velho
# ...                               ...                                  ...
# 5565                             5201                              Goiânia
# 5566                             5202                            Itumbiara
# 5567                             5206     Luziânia - Águas Lindas de Goiás
# 5568                             5205                   Porangatu - Uruaçu
# 5569                             5301                     Distrito Federal
#
#       Região Geográfica Imediata Nome Região Geográfica Imediata  \
# 0                         110005                          Cacoal
# 1                         110005                          Cacoal
# 2                         110002                       Ariquemes
# 3                         110004                       Ji-Paraná
# 4                         110002                       Ariquemes
# ...                          ...                             ...
# 5565                      520002                        Anápolis
# 5566                      520009                     Piracanjuba
# 5567                      520022                 Flores de Goiás
# 5568                      520018      Ceres - Rialma - Goianésia
# 5569                      530001                Distrito Federal
#
#       Mesorregião Geográfica   Nome_Mesorregião  Microrregião Geográfica  \
# 0                          2  Leste Rondoniense                        6
# 1                          2  Leste Rondoniense                        6
# 2                          2  Leste Rondoniense                        3
# 3                          2  Leste Rondoniense                        5
# 4                          2  Leste Rondoniense                        3
# ...                      ...                ...                      ...
# 5565                       5         Sul Goiano                       16
# 5566                       5         Sul Goiano                       15
# 5567                       4       Leste Goiano                       12
# 5568                       4       Leste Goiano                       12
# 5569                       1   Distrito Federal                        1
#
#         Nome_Microrregião  Município  Código Município Completo  \
# 0                  Cacoal         15                    1100015
# 1                  Cacoal        379                    1100379
# 2               Ariquemes        403                    1100403
# 3        Alvorada D'Oeste        346                    1100346
# 4               Ariquemes         23                    1100023
# ...                   ...        ...                        ...
# 5565         Pires do Rio      22005                    5222005
# 5566           Meia Ponte      22054                    5222054
# 5567  Entorno de Brasília      22203                    5222203
# 5568  Entorno de Brasília      22302                    5222302
# 5569             Brasília        108                    5300108
#
#                Nome_Município
# 0       Alta Floresta D'Oeste
# 1     Alto Alegre dos Parecis
# 2                Alto Paraíso
# 3            Alvorada D'Oeste
# 4                   Ariquemes
# ...                       ...
# 5565               Vianópolis
# 5566           Vicentinópolis
# 5567                 Vila Boa
# 5568            Vila Propício
# 5569                 Brasília
#
# [5570 rows x 11 columns]

# %%
df
# Out:
#         geo_id   ano  area_colhida_v0  area_plantada_dest_colheita_v0  \
# 0      1100015  2003          25084.0                         25114.0
# 1      1100023  2003          15253.0                         15933.0
# 2      1100031  2003           7672.0                          7722.0
# 3      1100049  2003          25929.0                         26274.0
# 4      1100056  2003           9623.0                          9680.0
# ...        ...   ...              ...                             ...
# 93442  2924652  2019              NaN                           700.0
# 93443  2925956  2019              NaN                          3200.0
# 93444  2930402  2019              NaN                          1552.0
# 93445  2616001  2019              NaN                           428.0
# 93446  3518800  2010              NaN                             NaN
#
#        valor_v0  area_colhida_v40092  area_plantada_dest_colheita_v40092  \
# 0       24813.0                  2.0                                 2.0
# 1       35136.0                 10.0                                10.0
# 2       13157.0                 16.0                                16.0
# 3       35099.0                 10.0                                10.0
# 4       15958.0                 10.0                                10.0
# ...         ...                  ...                                 ...
# 93442       NaN                  NaN                                 NaN
# 93443       NaN                  NaN                                 NaN
# 93444       NaN                  NaN                                 NaN
# 93445       NaN                  NaN                                 NaN
# 93446       0.0                  NaN                                 NaN
#
#        quant_v40092  rend_medio_v40092  valor_v40092  ...  \
# 0              39.0            19500.0          18.0  ...
# 1             166.0            16600.0          78.0  ...
# 2             296.0            18500.0         139.0  ...
# 3             185.0            18500.0          87.0  ...
# 4             175.0            17500.0          82.0  ...
# ...             ...                ...           ...  ...
# 93442           NaN                NaN           NaN  ...
# 93443           NaN                NaN           NaN  ...
# 93444           NaN                NaN           NaN  ...
# 93445           NaN                NaN           NaN  ...
# 93446           NaN                NaN           NaN  ...
#
#        area_colhida_v40274  area_plantada_dest_colheita_v40274  quant_v40274  \
# 0                      NaN                                 NaN           NaN
# 1                      1.0                                 1.0          11.0
# 2                      NaN                                 NaN           NaN
# 3                      1.0                                 1.0          11.0
# 4                      NaN                                 NaN           NaN
# ...                    ...                                 ...           ...
# 93442                  NaN                                 NaN           NaN
# 93443                  NaN                                 NaN           NaN
# 93444                  NaN                                 NaN           NaN
# 93445                  NaN                                 NaN           NaN
# 93446                  NaN                                 NaN           NaN
#
#        rend_medio_v40274  valor_v40274  area_colhida_v45982  \
# 0                    NaN           NaN                  NaN
# 1                11000.0           8.0                  NaN
# 2                    NaN           NaN                  NaN
# 3                11000.0           8.0                  NaN
# 4                    NaN           NaN                  NaN
# ...                  ...           ...                  ...
# 93442                NaN           NaN                  NaN
# 93443                NaN           NaN                  NaN
# 93444                NaN           NaN                  NaN
# 93445                NaN           NaN                  NaN
# 93446                NaN           NaN                  NaN
#
#        area_plantada_dest_colheita_v45982  quant_v45982  rend_medio_v45982  \
# 0                                     NaN           NaN                NaN
# 1                                     NaN           NaN                NaN
# 2                                     NaN           NaN                NaN
# 3                                     NaN           NaN                NaN
# 4                                     NaN           NaN                NaN
# ...                                   ...           ...                ...
# 93442                                 NaN           NaN                NaN
# 93443                                 NaN           NaN                NaN
# 93444                                 NaN           NaN                NaN
# 93445                                 NaN           NaN                NaN
# 93446                                 NaN           NaN                NaN
#
#        valor_v45982
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 93442           NaN
# 93443           NaN
# 93444           NaN
# 93445           NaN
# 93446           NaN
#
# [93447 rows x 340 columns]

# %%
municipios = ['Castanhal - PA', 'Araguaína - TO', 'Vilhena - RO', 'Ariquemes - RO', 'Barra do Garças - MT',
 'Brasiléia - AC', 'Manaus - AM', 'Rondonópolis - MT', 'Sinop - MT', 'Belém - PA', 'Ananindeua - PA',
 'Aripuanã - MT',
 'Balsas - MA',
 'Cuiabá - MT',
 'Ji-Paraná - RO',
 'São Luís - MA',
 'Poxoréo - MT',
 'Santana - AP',
 'Sapezal - MT',
 'Tomé-Açu - PA',
 'Araputanga - MT',
 'Candeias do Jamari - RO',
 'Oriximiná - PA',
 'Ponte Alta do Tocantins - TO',
 'Santarém - PA',
 'Pedra Branca do Amapari - AP',
 'Santa Rita do Trivelato - MT',
 'Almeirim - PA',
 'Alta Floresta - MT',
 'Anapu - PA',
 'Barcarena - PA',
 'Breves - PA',
 'Cotriguaçu - MT',
 'Juína - MT',
 'Marituba - PA',
 'Medicilândia - PA',
 'Porto de Moz - PA',
 'Prainha - PA',
 'São José do Rio Claro - MT',
 'Senador José Porfírio - PA',
 'Uruará - PA',
 'Cáceres - MT',
 'Epitaciolândia - AC',
 'Guajará-Mirim - RO',
 'Nobres - MT',
 'Porto Velho - RO',
 'Várzea Grande - MT',
 'Bragança - PA',
 'Paranaíta - MT',
 'Altamira - PA',
 'Canaã dos Carajás - PA',
 'Colniza - MT',
 'Dom Eliseu - PA',
 'Itaituba - PA',
 'Mazagão - AP',
 'Ouro Preto do Oeste - RO',
 'Parauapebas - PA',
 'Presidente Figueiredo - AM',
 'Rio Branco - AC',
 'Rolim de Moura - RO',
 'Xinguara - PA',
 'Campo Novo do Parecis - MT',
 'Campos de Júlio - MT',
 'Cerejeiras - RO',
 'Pedra Preta - MT',
 'Matupá - MT',
 'Itacoatiara - AM',
 'Juruena - MT',
 'Portel - PA',
 'Água Azul do Norte - PA',
 'Jaru - RO',
 'Marabá - PA',
 'Pimenta Bueno - RO',
 'Acará - PA',
 'Feliz Natal - MT',
 "Machadinho D'Oeste - RO",
 'Nova Mutum - MT',
 'Nova Ubiratã - MT',
 'Paragominas - PA',
 'Placas - PA',
 'Primavera do Leste - MT',
 'Santa Bárbara do Pará - PA',
 'Macapá - AP',
 'Lucas do Rio Verde - MT',
 'Breu Branco - PA',
 'São José de Ribamar - MA',
 'Tailândia - PA',
 'Boa Vista - RR',
 'Tucumã - PA',
 'Diamantino - MT',
 'Gurupi - TO',
 'Igarapé do Meio - MA',
 'Redenção - PA',
 'Santana do Araguaia - PA',
 'Rio Maria - PA',
 'Tangará da Serra - MT',
 'Peri Mirim - MA',
 'Alto Araguaia - MT',
 'Alto Taquari - MT',
 'Brasnorte - MT',
 'Campo Verde - MT',
 'Sorriso - MT',
 'Tapurah - MT',
 'Abaetetuba - PA',
 'Açailândia - MA',
 'Colorado do Oeste - RO',
 'Guarantã do Norte - MT',
 'Água Boa - MT',
 'Itiquira - MT',
 'Chaves - PA',
 'Ipiranga do Norte - MT',
 'Benevides - PA',
 'Cametá - PA',
 'Cantá - RR',
 'São Félix do Araguaia - MT',
 'Miracema do Tocantins - TO',
 'Novo Progresso - PA',
 'Porto Esperidião - MT',
 'Pontes e Lacerda - MT',
 'Tasso Fragoso - MA',
 'Afuá - PA',
 'Anajás - PA',
 'Chupinguaia - RO',
 'Floresta do Araguaia - PA',
 'Novo Aripuanã - AM',
 'Vigia - PA',
 'Peixe-Boi - PA',
 'Mucajaí - RR',
 'Pacaraima - RR',
 'Trairão - PA',
 'São José do Xingu - MT',
 'Colíder - MT',
 'São Miguel do Guaporé - RO',
 "Espigão D'Oeste - RO",
 'Óbidos - PA',
 'Juara - MT',
 'Santa Isabel do Pará - PA',
 'Nova Olinda - TO',
 'São José dos Quatro Marcos - MT',
 'Rosário Oeste - MT',
 'Alto Garças - MT',
 'Canarana - MT',
 'Comodoro - MT',
 'Lago do Junco - MA',
 'Vila Rica - MT',
 'Nova Lacerda - MT',
 'Paranatinga - MT',
 'Godofredo Viana - MA',
 'Vila Bela da Santíssima Trindade - MT',
 'Bacabeira - MA',
 'Ourilândia do Norte - PA',
 'Pacajá - PA',
 'Salvaterra - PA',
 'Nova Olímpia - MT',
 'São Luiz - RR',
 'Cujubim - RO',
 'Santo Antônio do Leste - MT',
 'Moju - PA',
 'Abel Figueiredo - PA',
 'Confresa - MT',
 'Paraíso do Tocantins - TO',
 'Jaciara - MT',
 'Santa Luzia do Paruá - MA',
 'Capanema - PA',
 'Querência - MT',
 'Santo Antônio do Leverger - MT',
 'Porto dos Gaúchos - MT',
 'Gaúcha do Norte - MT',
 'Bom Jesus do Araguaia - MT',
 'Augusto Corrêa - PA',
 'Dom Aquino - MT',
 'Rondon do Pará - PA',
 'Ipixuna do Pará - PA',
 'Campos Lindos - TO',
 'Barra do Corda - MA',
 'Tabaporã - MT',
 'Conceição do Araguaia - PA',
 'Nova Maringá - MT',
 'Monte Negro - RO',
 'Palmas - TO',
 'Santa Carmem - MT',
 "Mirassol d'Oeste - MT",
 'Porto Alegre do Norte - MT',
 'Porto Franco - MA',
 'São Félix do Xingu - PA',
 'Nova Xavantina - MT',
 'Iranduba - AM',
 'Loreto - MA',
 'Presidente Kennedy - TO',
 'Riachão - MA',
 'Acorizal - MT',
 'Miranorte - TO',
 'Marcelândia - MT',
 'Nova Santa Helena - MT',
 'Colinas do Tocantins - TO',
 'Governador Edison Lobão - MA',
 'Magalhães de Almeida - MA',
 'Porto Nacional - TO',
 'Maués - AM',
 'Santa Cruz do Xingu - MT',
 'Cláudia - MT',
 'Alvorada - TO',
 'Boca do Acre - AM',
 'Santo Antônio dos Lopes - MA',
 'Rorainópolis - RR',
 'General Carneiro - MT',
 'Nortelândia - MT',
 'Borba - AM',
 'Cacoal - RO',
 'Curionópolis - PA',
 'Imperatriz - MA',
 'Timon - MA',
 'Pedro Afonso - TO',
 'São Bernardo - MA',
 'Palmeirante - TO',
 'Santa Maria das Barreiras - PA',
 'Taguatinga - TO',
 'Vera - MT',
 'Itanhangá - MT',
 'Cariri do Tocantins - TO',
 'Alto Paraíso - RO',
 'Aguiarnópolis - TO',
 'Pindaré-Mirim - MA',
 'Manacapuru - AM',
 'Buritis - RO',
 'Mateiros - TO',
 'João Lisboa - MA',
 'Barra do Bugres - MT',
 'Itapuã do Oeste - RO',
 'Manoel Urbano - AC',
 'Juruti - PA',
 "Alta Floresta D'Oeste - RO",
 'Tutóia - MA',
 'Bonfim - RR',
 'São Geraldo do Araguaia - PA',
 'São Miguel do Tocantins - TO',
 'Ulianópolis - PA',
 'Nova Monte Verde - MT',
 'Senador Guiomard - AC',
 'Xapuri - AC',
 'Curuçá - PA',
 'Inhangapi - PA',
 'Muaná - PA',
 'União do Sul - MT',
 'Anapurus - MA',
 'Silvanópolis - TO',
 "Nova Brasilândia D'Oeste - RO",
 'Cumaru do Norte - PA',
 'Nova Canaã do Norte - MT',
 'Aurora do Pará - PA',
 'Poconé - MT',
 'Calçoene - AP',
 'Igarapé-Miri - PA',
 'Figueirópolis - TO',
 'Guaraí - TO',
 'São Domingos do Azeitão - MA',
 'São Domingos do Capim - PA',
 'Porto Grande - AP',
 'Rurópolis - PA',
 'Nossa Senhora do Livramento - MT',
 'Ribeirão Cascalheira - MT',
 'Tupirama - TO',
 'Novo Mundo - MT',
 'Urucará - AM',
 'Capitão Poço - PA',
 'Sambaíba - MA',
 'Santa Rosa do Tocantins - TO',
 "Pau D'Arco - PA",
 'Capixaba - AC',
 'Novo São Joaquim - MT',
 'Peixe - TO',
 'Presidente Médici - RO',
 'Salto do Céu - MT',
 'Humaitá - AM',
 'Porto Estrela - MT',
 'Peixoto de Azevedo - MT',
 'Piçarra - PA',
 'Tefé - AM',
 'Raposa - MA',
 'Cabixi - RO',
 'Arraias - TO',
 'Costa Marques - RO',
 'São Gabriel da Cachoeira - AM',
 'Torixoréu - MT',
 'Centro Novo do Maranhão - MA',
 'Parintins - AM',
 'Terra Nova do Norte - MT',
 'Tabatinga - AM',
 'Caracaraí - RR',
 'Araguacema - TO',
 'Fortaleza do Tabocão - TO',
 'Wanderlândia - TO',
 'Bujaru - PA',
 'Mocajuba - PA',
 'Alto Parnaíba - MA',
 'Codó - MA',
 'Xambioá - TO',
 'Axixá do Tocantins - TO',
 'Sena Madureira - AC',
 'Tucuruí - PA',
 'Santa Inês - MA',
 'Vitória do Xingu - PA',
 'Nova Timboteua - PA',
 'Nova Marilândia - MT',
 'Matões do Norte - MA',
 'Itaúba - MT',
 'Jangada - MT',
 'Coari - AM',
 'Mojuí dos Campos - PA',
 'Ministro Andreazza - RO',
 'Aldeias Altas - MA',
 'Ferreira Gomes - AP',
 'Tocantinópolis - TO',
 'Cruzeiro do Sul - AC',
 'Eldorado dos Carajás - PA',
 'São Valério da Natividade - TO',
 'Parecis - RO',
 'Campo Novo de Rondônia - RO',
 'Benjamin Constant - AM',
 'Serra do Navio - AP',
 'Lizarda - TO',
 'Santa Maria do Pará - PA',
 'Belterra - PA',
 "Glória D'Oeste - MT",
 'Apiacás - MT',
 'Pindorama do Tocantins - TO',
 'Dianópolis - TO',
 'Oiapoque - AP',
 'Itapecuru Mirim - MA',
 'São Raimundo das Mangabeiras - MA',
 'Chapada dos Guimarães - MT',
 'Lagoa da Confusão - TO',
 'Assis Brasil - AC',
 'Nova Nazaré - MT',
 'Jacundá - PA',
 'Maracaçumé - MA',
 'Rondolândia - MT',
 'Paranã - TO',
 'Barão de Grajaú - MA',
 'Silves - AM',
 'Tartarugalzinho - AP',
 'Bonito - PA',
 'Nova Olinda do Norte - AM',
 'Caseara - TO',
 'Tocantínia - TO',
 'São João de Pirabas - PA']

# %%
list(df.columns)
# Out:
# ['geo_id',
#  'ano',
#  'area_colhida_v0',
#  'area_plantada_dest_colheita_v0',
#  'valor_v0',
#  'area_colhida_v40092',
#  'area_plantada_dest_colheita_v40092',
#  'quant_v40092',
#  'rend_medio_v40092',
#  'valor_v40092',
#  'area_colhida_v40099',
#  'area_plantada_dest_colheita_v40099',
#  'quant_v40099',
#  'rend_medio_v40099',
#  'valor_v40099',
#  'area_colhida_v40100',
#  'area_plantada_dest_colheita_v40100',
#  'quant_v40100',
#  'rend_medio_v40100',
#  'valor_v40100',
#  'area_colhida_v40101',
#  'area_plantada_dest_colheita_v40101',
#  'quant_v40101',
#  'rend_medio_v40101',
#  'valor_v40101',
#  'area_colhida_v40102',
#  'area_plantada_dest_colheita_v40102',
#  'quant_v40102',
#  'rend_medio_v40102',
#  'valor_v40102',
#  'area_colhida_v40103',
#  'area_plantada_dest_colheita_v40103',
#  'quant_v40103',
#  'rend_medio_v40103',
#  'valor_v40103',
#  'area_colhida_v40104',
#  'area_plantada_dest_colheita_v40104',
#  'quant_v40104',
#  'rend_medio_v40104',
#  'valor_v40104',
#  'area_colhida_v40105',
#  'area_plantada_dest_colheita_v40105',
#  'quant_v40105',
#  'rend_medio_v40105',
#  'valor_v40105',
#  'area_colhida_v40106',
#  'area_plantada_dest_colheita_v40106',
#  'quant_v40106',
#  'rend_medio_v40106',
#  'valor_v40106',
#  'area_colhida_v40107',
#  'area_plantada_dest_colheita_v40107',
#  'quant_v40107',
#  'rend_medio_v40107',
#  'valor_v40107',
#  'area_colhida_v40108',
#  'area_plantada_dest_colheita_v40108',
#  'quant_v40108',
#  'rend_medio_v40108',
#  'valor_v40108',
#  'area_colhida_v40109',
#  'area_plantada_dest_colheita_v40109',
#  'quant_v40109',
#  'rend_medio_v40109',
#  'valor_v40109',
#  'area_colhida_v40110',
#  'area_plantada_dest_colheita_v40110',
#  'quant_v40110',
#  'rend_medio_v40110',
#  'valor_v40110',
#  'area_colhida_v40111',
#  'area_plantada_dest_colheita_v40111',
#  'quant_v40111',
#  'rend_medio_v40111',
#  'valor_v40111',
#  'area_colhida_v40112',
#  'area_plantada_dest_colheita_v40112',
#  'quant_v40112',
#  'rend_medio_v40112',
#  'valor_v40112',
#  'area_colhida_v40113',
#  'area_plantada_dest_colheita_v40113',
#  'quant_v40113',
#  'rend_medio_v40113',
#  'valor_v40113',
#  'area_colhida_v40114',
#  'area_plantada_dest_colheita_v40114',
#  'quant_v40114',
#  'rend_medio_v40114',
#  'valor_v40114',
#  'area_colhida_v40115',
#  'area_plantada_dest_colheita_v40115',
#  'quant_v40115',
#  'rend_medio_v40115',
#  'valor_v40115',
#  'area_colhida_v40116',
#  'area_plantada_dest_colheita_v40116',
#  'quant_v40116',
#  'rend_medio_v40116',
#  'valor_v40116',
#  'area_colhida_v40117',
#  'area_plantada_dest_colheita_v40117',
#  'quant_v40117',
#  'rend_medio_v40117',
#  'valor_v40117',
#  'area_colhida_v40118',
#  'area_plantada_dest_colheita_v40118',
#  'quant_v40118',
#  'rend_medio_v40118',
#  'valor_v40118',
#  'area_colhida_v40119',
#  'area_plantada_dest_colheita_v40119',
#  'quant_v40119',
#  'rend_medio_v40119',
#  'valor_v40119',
#  'area_colhida_v40120',
#  'area_plantada_dest_colheita_v40120',
#  'quant_v40120',
#  'rend_medio_v40120',
#  'valor_v40120',
#  'area_colhida_v40121',
#  'area_plantada_dest_colheita_v40121',
#  'quant_v40121',
#  'rend_medio_v40121',
#  'valor_v40121',
#  'area_colhida_v40122',
#  'area_plantada_dest_colheita_v40122',
#  'quant_v40122',
#  'rend_medio_v40122',
#  'valor_v40122',
#  'area_colhida_v40123',
#  'area_plantada_dest_colheita_v40123',
#  'quant_v40123',
#  'rend_medio_v40123',
#  'valor_v40123',
#  'area_colhida_v40124',
#  'area_plantada_dest_colheita_v40124',
#  'quant_v40124',
#  'rend_medio_v40124',
#  'valor_v40124',
#  'area_colhida_v40125',
#  'area_plantada_dest_colheita_v40125',
#  'quant_v40125',
#  'rend_medio_v40125',
#  'valor_v40125',
#  'area_colhida_v40126',
#  'area_plantada_dest_colheita_v40126',
#  'quant_v40126',
#  'rend_medio_v40126',
#  'valor_v40126',
#  'area_colhida_v40127',
#  'area_plantada_dest_colheita_v40127',
#  'quant_v40127',
#  'rend_medio_v40127',
#  'valor_v40127',
#  'area_colhida_v40128',
#  'area_plantada_dest_colheita_v40128',
#  'quant_v40128',
#  'rend_medio_v40128',
#  'valor_v40128',
#  'area_colhida_v40129',
#  'area_plantada_dest_colheita_v40129',
#  'quant_v40129',
#  'rend_medio_v40129',
#  'valor_v40129',
#  'area_colhida_v40130',
#  'area_plantada_dest_colheita_v40130',
#  'quant_v40130',
#  'rend_medio_v40130',
#  'valor_v40130',
#  'area_colhida_v40131',
#  'area_plantada_dest_colheita_v40131',
#  'quant_v40131',
#  'rend_medio_v40131',
#  'valor_v40131',
#  'area_colhida_v40136',
#  'area_plantada_dest_colheita_v40136',
#  'quant_v40136',
#  'rend_medio_v40136',
#  'valor_v40136',
#  'area_colhida_v40137',
#  'area_plantada_dest_colheita_v40137',
#  'quant_v40137',
#  'rend_medio_v40137',
#  'valor_v40137',
#  'area_colhida_v40138',
#  'area_plantada_dest_colheita_v40138',
#  'quant_v40138',
#  'rend_medio_v40138',
#  'valor_v40138',
#  'area_colhida_v40139',
#  'area_plantada_dest_colheita_v40139',
#  'quant_v40139',
#  'rend_medio_v40139',
#  'valor_v40139',
#  'area_colhida_v40140',
#  'area_plantada_dest_colheita_v40140',
#  'quant_v40140',
#  'rend_medio_v40140',
#  'valor_v40140',
#  'area_colhida_v40141',
#  'area_plantada_dest_colheita_v40141',
#  'quant_v40141',
#  'rend_medio_v40141',
#  'valor_v40141',
#  'area_colhida_v40142',
#  'area_plantada_dest_colheita_v40142',
#  'quant_v40142',
#  'rend_medio_v40142',
#  'valor_v40142',
#  'area_colhida_v40143',
#  'area_plantada_dest_colheita_v40143',
#  'quant_v40143',
#  'rend_medio_v40143',
#  'valor_v40143',
#  'area_colhida_v40144',
#  'area_plantada_dest_colheita_v40144',
#  'quant_v40144',
#  'rend_medio_v40144',
#  'valor_v40144',
#  'area_colhida_v40145',
#  'area_plantada_dest_colheita_v40145',
#  'quant_v40145',
#  'rend_medio_v40145',
#  'valor_v40145',
#  'area_colhida_v40146',
#  'area_plantada_dest_colheita_v40146',
#  'quant_v40146',
#  'rend_medio_v40146',
#  'valor_v40146',
#  'area_colhida_v40147',
#  'area_plantada_dest_colheita_v40147',
#  'quant_v40147',
#  'rend_medio_v40147',
#  'valor_v40147',
#  'area_colhida_v40148',
#  'area_plantada_dest_colheita_v40148',
#  'quant_v40148',
#  'rend_medio_v40148',
#  'valor_v40148',
#  'area_colhida_v40149',
#  'area_plantada_dest_colheita_v40149',
#  'quant_v40149',
#  'rend_medio_v40149',
#  'valor_v40149',
#  'area_colhida_v40150',
#  'area_plantada_dest_colheita_v40150',
#  'quant_v40150',
#  'rend_medio_v40150',
#  'valor_v40150',
#  'area_colhida_v40151',
#  'area_plantada_dest_colheita_v40151',
#  'quant_v40151',
#  'rend_medio_v40151',
#  'valor_v40151',
#  'area_colhida_v40152',
#  'area_plantada_dest_colheita_v40152',
#  'quant_v40152',
#  'rend_medio_v40152',
#  'valor_v40152',
#  'area_colhida_v40260',
#  'area_plantada_dest_colheita_v40260',
#  'quant_v40260',
#  'rend_medio_v40260',
#  'valor_v40260',
#  'area_colhida_v40261',
#  'area_plantada_dest_colheita_v40261',
#  'quant_v40261',
#  'rend_medio_v40261',
#  'valor_v40261',
#  'area_colhida_v40262',
#  'area_plantada_dest_colheita_v40262',
#  'quant_v40262',
#  'rend_medio_v40262',
#  'valor_v40262',
#  'area_colhida_v40263',
#  'area_plantada_dest_colheita_v40263',
#  'quant_v40263',
#  'rend_medio_v40263',
#  'valor_v40263',
#  'area_colhida_v40264',
#  'area_plantada_dest_colheita_v40264',
#  'quant_v40264',
#  'rend_medio_v40264',
#  'valor_v40264',
#  'area_colhida_v40265',
#  'area_plantada_dest_colheita_v40265',
#  'quant_v40265',
#  'rend_medio_v40265',
#  'valor_v40265',
#  'area_colhida_v40266',
#  'area_plantada_dest_colheita_v40266',
#  'quant_v40266',
#  'rend_medio_v40266',
#  'valor_v40266',
#  'area_colhida_v40267',
#  'area_plantada_dest_colheita_v40267',
#  'quant_v40267',
#  'rend_medio_v40267',
#  'valor_v40267',
#  'area_colhida_v40268',
#  'area_plantada_dest_colheita_v40268',
#  'quant_v40268',
#  'rend_medio_v40268',
#  'valor_v40268',
#  'area_colhida_v40269',
#  'area_plantada_dest_colheita_v40269',
#  'quant_v40269',
#  'rend_medio_v40269',
#  'valor_v40269',
#  'area_colhida_v40270',
#  'area_plantada_dest_colheita_v40270',
#  'quant_v40270',
#  'rend_medio_v40270',
#  'valor_v40270',
#  'area_colhida_v40271',
#  'area_plantada_dest_colheita_v40271',
#  'quant_v40271',
#  'rend_medio_v40271',
#  'valor_v40271',
#  'area_colhida_v40272',
#  'area_plantada_dest_colheita_v40272',
#  'quant_v40272',
#  'rend_medio_v40272',
#  'valor_v40272',
#  'area_colhida_v40273',
#  'area_plantada_dest_colheita_v40273',
#  'quant_v40273',
#  'rend_medio_v40273',
#  'valor_v40273',
#  'area_colhida_v40274',
#  'area_plantada_dest_colheita_v40274',
#  'quant_v40274',
#  'rend_medio_v40274',
#  'valor_v40274',
#  'area_colhida_v45982',
#  'area_plantada_dest_colheita_v45982',
#  'quant_v45982',
#  'rend_medio_v45982',
#  'valor_v45982']

# %%
df.shape
# Out:
# (93447, 340)

# %%
df.isnull().sum()
# Out:
# geo_id                                    0
# ano                                       0
# area_colhida_v0                          86
# area_plantada_dest_colheita_v0            1
# valor_v0                                 86
#                                       ...
# area_colhida_v45982                   92570
# area_plantada_dest_colheita_v45982    92567
# quant_v45982                          92570
# rend_medio_v45982                     92570
# valor_v45982                          92570
# Length: 340, dtype: int64

# %%
xl = pd.ExcelFile(filepath)

xl.sheet_names  # see all sheet names

# xl.parse(sheet_name)  # read a specific sheet to DataFrame
# Out:
# ['Dados', 'Dicionário', 'Variáveis externas']

# %%
xl.parse('Dados')
# Out:
#         geo_id   ano  area_colhida_v0  area_plantada_dest_colheita_v0  \
# 0      1100015  2003          25084.0                         25114.0
# 1      1100023  2003          15253.0                         15933.0
# 2      1100031  2003           7672.0                          7722.0
# 3      1100049  2003          25929.0                         26274.0
# 4      1100056  2003           9623.0                          9680.0
# ...        ...   ...              ...                             ...
# 93442  2924652  2019              NaN                           700.0
# 93443  2925956  2019              NaN                          3200.0
# 93444  2930402  2019              NaN                          1552.0
# 93445  2616001  2019              NaN                           428.0
# 93446  3518800  2010              NaN                             NaN
#
#        valor_v0  area_colhida_v40092  area_plantada_dest_colheita_v40092  \
# 0       24813.0                  2.0                                 2.0
# 1       35136.0                 10.0                                10.0
# 2       13157.0                 16.0                                16.0
# 3       35099.0                 10.0                                10.0
# 4       15958.0                 10.0                                10.0
# ...         ...                  ...                                 ...
# 93442       NaN                  NaN                                 NaN
# 93443       NaN                  NaN                                 NaN
# 93444       NaN                  NaN                                 NaN
# 93445       NaN                  NaN                                 NaN
# 93446       0.0                  NaN                                 NaN
#
#        quant_v40092  rend_medio_v40092  valor_v40092  ...  \
# 0              39.0            19500.0          18.0  ...
# 1             166.0            16600.0          78.0  ...
# 2             296.0            18500.0         139.0  ...
# 3             185.0            18500.0          87.0  ...
# 4             175.0            17500.0          82.0  ...
# ...             ...                ...           ...  ...
# 93442           NaN                NaN           NaN  ...
# 93443           NaN                NaN           NaN  ...
# 93444           NaN                NaN           NaN  ...
# 93445           NaN                NaN           NaN  ...
# 93446           NaN                NaN           NaN  ...
#
#        area_colhida_v40274  area_plantada_dest_colheita_v40274  quant_v40274  \
# 0                      NaN                                 NaN           NaN
# 1                      1.0                                 1.0          11.0
# 2                      NaN                                 NaN           NaN
# 3                      1.0                                 1.0          11.0
# 4                      NaN                                 NaN           NaN
# ...                    ...                                 ...           ...
# 93442                  NaN                                 NaN           NaN
# 93443                  NaN                                 NaN           NaN
# 93444                  NaN                                 NaN           NaN
# 93445                  NaN                                 NaN           NaN
# 93446                  NaN                                 NaN           NaN
#
#        rend_medio_v40274  valor_v40274  area_colhida_v45982  \
# 0                    NaN           NaN                  NaN
# 1                11000.0           8.0                  NaN
# 2                    NaN           NaN                  NaN
# 3                11000.0           8.0                  NaN
# 4                    NaN           NaN                  NaN
# ...                  ...           ...                  ...
# 93442                NaN           NaN                  NaN
# 93443                NaN           NaN                  NaN
# 93444                NaN           NaN                  NaN
# 93445                NaN           NaN                  NaN
# 93446                NaN           NaN                  NaN
#
#        area_plantada_dest_colheita_v45982  quant_v45982  rend_medio_v45982  \
# 0                                     NaN           NaN                NaN
# 1                                     NaN           NaN                NaN
# 2                                     NaN           NaN                NaN
# 3                                     NaN           NaN                NaN
# 4                                     NaN           NaN                NaN
# ...                                   ...           ...                ...
# 93442                                 NaN           NaN                NaN
# 93443                                 NaN           NaN                NaN
# 93444                                 NaN           NaN                NaN
# 93445                                 NaN           NaN                NaN
# 93446                                 NaN           NaN                NaN
#
#        valor_v45982
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 93442           NaN
# 93443           NaN
# 93444           NaN
# 93445           NaN
# 93446           NaN
#
# [93447 rows x 340 columns]

# %%
xl.parse('Dicionário')
# Out:
#                                variable  value    label    meta
# 0                       area_colhida_v0    NaN    Total  varlab
# 1        area_plantada_dest_colheita_v0    NaN    Total  varlab
# 2                              valor_v0    NaN    Total  varlab
# 3                   area_colhida_v40092    NaN  Abacaxi  varlab
# 4    area_plantada_dest_colheita_v40092    NaN  Abacaxi  varlab
# ..                                  ...    ...      ...     ...
# 333                 area_colhida_v45982    NaN     Acai  varlab
# 334  area_plantada_dest_colheita_v45982    NaN     Acai  varlab
# 335                        quant_v45982    NaN     Acai  varlab
# 336                   rend_medio_v45982    NaN     Acai  varlab
# 337                        valor_v45982    NaN     Acai  varlab
#
# [338 rows x 4 columns]

# %%
xl.parse('Variáveis externas')
# Out:
#       Região Geográfica Intermediária Nome Região Geográfica Intermediária  \
# 0                                1102                            Ji-Paraná
# 1                                1102                            Ji-Paraná
# 2                                1101                          Porto Velho
# 3                                1102                            Ji-Paraná
# 4                                1101                          Porto Velho
# ...                               ...                                  ...
# 5565                             5201                              Goiânia
# 5566                             5202                            Itumbiara
# 5567                             5206     Luziânia - Águas Lindas de Goiás
# 5568                             5205                   Porangatu - Uruaçu
# 5569                             5301                     Distrito Federal
#
#       Região Geográfica Imediata Nome Região Geográfica Imediata  \
# 0                         110005                          Cacoal
# 1                         110005                          Cacoal
# 2                         110002                       Ariquemes
# 3                         110004                       Ji-Paraná
# 4                         110002                       Ariquemes
# ...                          ...                             ...
# 5565                      520002                        Anápolis
# 5566                      520009                     Piracanjuba
# 5567                      520022                 Flores de Goiás
# 5568                      520018      Ceres - Rialma - Goianésia
# 5569                      530001                Distrito Federal
#
#       Mesorregião Geográfica   Nome_Mesorregião  Microrregião Geográfica  \
# 0                          2  Leste Rondoniense                        6
# 1                          2  Leste Rondoniense                        6
# 2                          2  Leste Rondoniense                        3
# 3                          2  Leste Rondoniense                        5
# 4                          2  Leste Rondoniense                        3
# ...                      ...                ...                      ...
# 5565                       5         Sul Goiano                       16
# 5566                       5         Sul Goiano                       15
# 5567                       4       Leste Goiano                       12
# 5568                       4       Leste Goiano                       12
# 5569                       1   Distrito Federal                        1
#
#         Nome_Microrregião  Município  Código Município Completo  \
# 0                  Cacoal         15                    1100015
# 1                  Cacoal        379                    1100379
# 2               Ariquemes        403                    1100403
# 3        Alvorada D'Oeste        346                    1100346
# 4               Ariquemes         23                    1100023
# ...                   ...        ...                        ...
# 5565         Pires do Rio      22005                    5222005
# 5566           Meia Ponte      22054                    5222054
# 5567  Entorno de Brasília      22203                    5222203
# 5568  Entorno de Brasília      22302                    5222302
# 5569             Brasília        108                    5300108
#
#                Nome_Município
# 0       Alta Floresta D'Oeste
# 1     Alto Alegre dos Parecis
# 2                Alto Paraíso
# 3            Alvorada D'Oeste
# 4                   Ariquemes
# ...                       ...
# 5565               Vianópolis
# 5566           Vicentinópolis
# 5567                 Vila Boa
# 5568            Vila Propício
# 5569                 Brasília
#
# [5570 rows x 11 columns]
